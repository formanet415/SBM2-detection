# %%
# Import cell
import numpy as np
import pickle

# %%
# Getting number of events in rolling buffer (DT_LW)
def AMP_Check(AMP, EPEAK_THRESH): 
    return AMP>EPEAK_THRESH

def EVENTS_Check(NR, NW_THRES): 
    return NR>NW_THRES

def FREQ_Check(Fp, FP_MIN, FP_MAX, RUA): 
    fmin = Fp>(FP_MIN/RUA)
    fmax = Fp<(FP_MAX/RUA)
    temp = fmin.astype(int)+fmax.astype(int)
    temp[temp<2] = 0
    temp[temp==2] = 1
    return temp

def SBM2_Check(AMP, NR, FP, EPEAK_THRESH, NW_THRES, FP_MIN, FP_MAX, RUA):
    A = AMP_Check(AMP, EPEAK_THRESH)
    E = EVENTS_Check(NR, NW_THRES)
    F = FREQ_Check(FP, FP_MIN, FP_MAX, RUA)
    A = A.astype(int)
    E = E.astype(int)
    F = F.astype(int)
    temp = A + E + F
    temp[temp<3] = 0
    temp[temp==3] = 1
    temp = temp.astype(int)
    return temp

def set_conf(conf):
    EPEAK_THRES = conf['EPEAK_THRES']
    FP_MIN = conf['FP_MIN'] * 0.5
    FP_MAX = conf['FP_MAX'] * 0.5
    NW_THRES = conf['NW_THRES']
    DT_LW = conf['DT_LW']
    N_LW_THRES = conf['N_LW_THRES']
    return EPEAK_THRES, FP_MIN, FP_MAX, NW_THRES, DT_LW, N_LW_THRES

def evaluate(conf):
    EPEAK_THRES, FP_MIN, FP_MAX, NW_THRES, DT_LW, N_LW_THRES = set_conf(conf)
    
    with open('SBM2_raw_data_V6.pickle', 'rb') as f:
        FP, AMP, NR = pickle.load(f)
    with open('SBM2_timepos_data_V6.pickle', 'rb') as f:
        time, rua, Epoch, et = pickle.load(f)
    
    EV = SBM2_Check(AMP, NR, FP, EPEAK_THRES, NW_THRES, FP_MIN, FP_MAX, rua)
    EVi = list(np.where(EV==1))[0]
    
    Ep = Epoch*1e-9
    times = np.array([])
    for i in list(EVi.tolist()):
        E1 = Ep[i]
        temp = Ep[0:i]
        SE = np.sum(EV[np.where(temp>E1-DT_LW)])
        if SE>N_LW_THRES:
            times = np.append(times, time[i])
    
    sbm = ['2021/05/22','2021/05/23','2020/12/09','2020/12/10','2020/12/11','2020/12/12','2020/12/13','2020/11/18','2021/05/09','2020/11/17','2021/05/29','2020/12/14']
    fp  = ['2021/06/01','2021/06/04','2021/06/08','2021/05/10','2021/01/13','2021/01/14','2020/12/06','2020/08/31','2020/08/27','2020/08/29','2020/07/24','2020/04/19','2020/04/18','2020/05/02','2020/07/10','2020/12/17','2021/03/27','2021/03/20','2021/05/31','2021/01/05','2021/03/19','2020/12/27','2020/05/30','2020/07/23','2020/08/04','2020/11/24','2020/12/20','2021/06/07','','','','','','','','','','','','','','']
    
    correct = 0
    incorrect = 0 
    dates = np.array([])
    for i in range(times.size):
        date = times[i].strftime('%Y/%m/%d - %H')
        dates = np.append(dates, date)

    for i in dates:
        if i[0:10] in sbm:
            print('correct: '+i)
            correct = correct +1
        else:
            incorrect = incorrect + 1 
            if i[0:10] not in fp:
                print('check ' + i)
            else:
                print('incorrect: ' + i)
    return times

# %%
a = evaluate(condef)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-c84cbe82c02f> in <module>
# ----> 1 a = evaluate(condef)
#
# <ipython-input-98-7ae3fd31aeb9> in evaluate(conf)
#      67
#      68     for i in dates:
# ---> 69         if i[0:10] in sbm:
#      70             print('correct: '+i)
#      71             correct = correct +1
#
# TypeError: 'datetime.datetime' object is not subscriptable

# %%
a
# Out:
# array([datetime.datetime(2020, 7, 10, 10, 37, 57, 843),
#        datetime.datetime(2020, 11, 17, 13, 58, 36, 35),
#        datetime.datetime(2020, 11, 17, 13, 58, 52, 35),
#        datetime.datetime(2020, 11, 17, 13, 59, 8, 35),
#        datetime.datetime(2020, 11, 17, 13, 59, 24, 35),
#        datetime.datetime(2020, 11, 17, 13, 59, 40, 35),
#        datetime.datetime(2020, 11, 17, 13, 59, 56, 35),
#        datetime.datetime(2020, 11, 17, 14, 0, 12, 35),
#        datetime.datetime(2020, 11, 17, 14, 0, 28, 35),
#        datetime.datetime(2020, 11, 17, 14, 0, 44, 35),
#        datetime.datetime(2020, 11, 17, 14, 1, 0, 35),
#        datetime.datetime(2020, 11, 17, 14, 1, 16, 35),
#        datetime.datetime(2020, 11, 17, 14, 1, 32, 35),
#        datetime.datetime(2020, 11, 17, 14, 1, 48, 35),
#        datetime.datetime(2020, 11, 17, 14, 2, 20, 35),
#        datetime.datetime(2020, 11, 17, 14, 2, 36, 35),
#        datetime.datetime(2020, 11, 17, 14, 2, 52, 35),
#        datetime.datetime(2020, 11, 17, 14, 3, 8, 35),
#        datetime.datetime(2020, 11, 17, 14, 3, 24, 35),
#        datetime.datetime(2020, 11, 17, 14, 4, 28, 35),
#        datetime.datetime(2020, 11, 17, 14, 4, 44, 36),
#        datetime.datetime(2020, 11, 17, 14, 5, 0, 36),
#        datetime.datetime(2020, 11, 17, 14, 5, 16, 36),
#        datetime.datetime(2020, 11, 17, 14, 5, 32, 36),
#        datetime.datetime(2020, 11, 17, 14, 5, 48, 36),
#        datetime.datetime(2020, 11, 17, 14, 6, 4, 36),
#        datetime.datetime(2020, 11, 17, 14, 6, 20, 36),
#        datetime.datetime(2020, 12, 27, 3, 23, 27, 725),
#        datetime.datetime(2020, 12, 27, 3, 25, 51, 725),
#        datetime.datetime(2020, 12, 27, 3, 26, 7, 725),
#        datetime.datetime(2020, 12, 27, 3, 26, 39, 725),
#        datetime.datetime(2020, 12, 27, 3, 27, 27, 725),
#        datetime.datetime(2020, 12, 27, 3, 28, 47, 725),
#        datetime.datetime(2020, 12, 27, 3, 29, 3, 725),
#        datetime.datetime(2020, 12, 27, 3, 30, 39, 725),
#        datetime.datetime(2020, 12, 27, 4, 46, 7, 733),
#        datetime.datetime(2020, 12, 27, 4, 46, 39, 733),
#        datetime.datetime(2020, 12, 27, 4, 46, 55, 733),
#        datetime.datetime(2020, 12, 27, 4, 47, 43, 733),
#        datetime.datetime(2020, 12, 27, 4, 48, 15, 733),
#        datetime.datetime(2020, 12, 27, 4, 48, 47, 733),
#        datetime.datetime(2020, 12, 27, 4, 49, 3, 733),
#        datetime.datetime(2020, 12, 27, 4, 49, 51, 733),
#        datetime.datetime(2020, 12, 27, 4, 50, 7, 733),
#        datetime.datetime(2020, 12, 27, 4, 50, 23, 733),
#        datetime.datetime(2020, 12, 27, 4, 50, 39, 733),
#        datetime.datetime(2020, 12, 27, 4, 50, 55, 733),
#        datetime.datetime(2020, 12, 27, 4, 51, 11, 733),
#        datetime.datetime(2020, 12, 27, 4, 51, 59, 733),
#        datetime.datetime(2020, 12, 27, 5, 20, 47, 736),
#        datetime.datetime(2020, 12, 27, 5, 21, 3, 736),
#        datetime.datetime(2020, 12, 27, 5, 21, 19, 736),
#        datetime.datetime(2020, 12, 27, 5, 21, 35, 736),
#        datetime.datetime(2020, 12, 27, 5, 21, 51, 736),
#        datetime.datetime(2020, 12, 27, 5, 22, 23, 737),
#        datetime.datetime(2020, 12, 27, 5, 25, 19, 737),
#        datetime.datetime(2020, 12, 27, 5, 25, 35, 737),
#        datetime.datetime(2020, 12, 27, 5, 25, 51, 737),
#        datetime.datetime(2020, 12, 27, 5, 26, 7, 737),
#        datetime.datetime(2020, 12, 27, 5, 26, 23, 737),
#        datetime.datetime(2020, 12, 27, 5, 26, 55, 737),
#        datetime.datetime(2020, 12, 27, 5, 28, 15, 737),
#        datetime.datetime(2020, 12, 27, 5, 28, 31, 737),
#        datetime.datetime(2020, 12, 27, 5, 28, 47, 737),
#        datetime.datetime(2020, 12, 27, 5, 30, 55, 737),
#        datetime.datetime(2020, 12, 27, 5, 31, 43, 737),
#        datetime.datetime(2020, 12, 27, 5, 31, 59, 738),
#        datetime.datetime(2020, 12, 27, 5, 32, 15, 738),
#        datetime.datetime(2020, 12, 27, 5, 32, 31, 738),
#        datetime.datetime(2020, 12, 27, 5, 32, 47, 738),
#        datetime.datetime(2020, 12, 27, 5, 33, 3, 738),
#        datetime.datetime(2020, 12, 27, 5, 35, 27, 738),
#        datetime.datetime(2020, 12, 27, 5, 51, 27, 739),
#        datetime.datetime(2020, 12, 27, 5, 51, 43, 739),
#        datetime.datetime(2020, 12, 27, 5, 52, 15, 740),
#        datetime.datetime(2020, 12, 27, 5, 52, 31, 740),
#        datetime.datetime(2020, 12, 27, 5, 52, 47, 740),
#        datetime.datetime(2020, 12, 27, 5, 53, 19, 740),
#        datetime.datetime(2020, 12, 27, 5, 53, 35, 740),
#        datetime.datetime(2020, 12, 27, 5, 55, 59, 740),
#        datetime.datetime(2020, 12, 27, 6, 54, 11, 746),
#        datetime.datetime(2020, 12, 27, 6, 54, 59, 746),
#        datetime.datetime(2020, 12, 27, 6, 55, 31, 746),
#        datetime.datetime(2020, 12, 27, 6, 55, 47, 746),
#        datetime.datetime(2020, 12, 27, 6, 57, 23, 746),
#        datetime.datetime(2020, 12, 27, 6, 57, 55, 746),
#        datetime.datetime(2020, 12, 27, 7, 10, 59, 747),
#        datetime.datetime(2020, 12, 27, 7, 11, 15, 747),
#        datetime.datetime(2020, 12, 27, 7, 12, 19, 748),
#        datetime.datetime(2020, 12, 27, 7, 13, 23, 748),
#        datetime.datetime(2020, 12, 27, 7, 13, 55, 748),
#        datetime.datetime(2020, 12, 27, 7, 14, 11, 748),
#        datetime.datetime(2020, 12, 27, 7, 14, 43, 748),
#        datetime.datetime(2020, 12, 27, 7, 38, 11, 750),
#        datetime.datetime(2020, 12, 27, 7, 38, 27, 750),
#        datetime.datetime(2020, 12, 27, 7, 39, 47, 750),
#        datetime.datetime(2020, 12, 27, 7, 40, 19, 750),
#        datetime.datetime(2020, 12, 27, 7, 41, 39, 751),
#        datetime.datetime(2020, 12, 27, 7, 41, 55, 751),
#        datetime.datetime(2020, 12, 27, 7, 42, 11, 751),
#        datetime.datetime(2020, 12, 27, 7, 42, 27, 751),
#        datetime.datetime(2020, 12, 27, 7, 42, 43, 751),
#        datetime.datetime(2020, 12, 27, 7, 42, 59, 751),
#        datetime.datetime(2020, 12, 27, 7, 44, 3, 751),
#        datetime.datetime(2020, 12, 27, 7, 44, 19, 751),
#        datetime.datetime(2020, 12, 27, 7, 46, 27, 751),
#        datetime.datetime(2020, 12, 27, 8, 10, 43, 753),
#        datetime.datetime(2020, 12, 27, 8, 10, 59, 753),
#        datetime.datetime(2020, 12, 27, 8, 11, 15, 753),
#        datetime.datetime(2020, 12, 27, 8, 11, 47, 754),
#        datetime.datetime(2020, 12, 27, 8, 13, 39, 754),
#        datetime.datetime(2020, 12, 27, 8, 14, 11, 754),
#        datetime.datetime(2020, 12, 27, 8, 14, 27, 754),
#        datetime.datetime(2020, 12, 27, 8, 14, 43, 754),
#        datetime.datetime(2020, 12, 27, 8, 14, 59, 754),
#        datetime.datetime(2020, 12, 27, 8, 15, 15, 754),
#        datetime.datetime(2020, 12, 27, 8, 15, 31, 754),
#        datetime.datetime(2020, 12, 27, 8, 15, 47, 754),
#        datetime.datetime(2020, 12, 27, 8, 16, 3, 754),
#        datetime.datetime(2020, 12, 27, 8, 17, 7, 754),
#        datetime.datetime(2020, 12, 27, 8, 17, 55, 754),
#        datetime.datetime(2020, 12, 27, 8, 18, 11, 754),
#        datetime.datetime(2020, 12, 27, 8, 18, 27, 754),
#        datetime.datetime(2020, 12, 27, 8, 18, 59, 754),
#        datetime.datetime(2020, 12, 27, 8, 19, 31, 754),
#        datetime.datetime(2020, 12, 27, 8, 19, 47, 754),
#        datetime.datetime(2020, 12, 27, 8, 20, 3, 754),
#        datetime.datetime(2020, 12, 27, 8, 21, 7, 754),
#        datetime.datetime(2020, 12, 27, 8, 21, 23, 755),
#        datetime.datetime(2020, 12, 27, 8, 22, 43, 755),
#        datetime.datetime(2020, 12, 27, 8, 23, 15, 755),
#        datetime.datetime(2020, 12, 27, 8, 23, 31, 755),
#        datetime.datetime(2020, 12, 27, 8, 24, 3, 755),
#        datetime.datetime(2020, 12, 27, 8, 24, 19, 755),
#        datetime.datetime(2020, 12, 27, 8, 24, 35, 755),
#        datetime.datetime(2020, 12, 27, 8, 24, 51, 755),
#        datetime.datetime(2020, 12, 27, 8, 25, 23, 755),
#        datetime.datetime(2020, 12, 27, 8, 25, 39, 755),
#        datetime.datetime(2020, 12, 27, 8, 26, 59, 755),
#        datetime.datetime(2020, 12, 27, 8, 33, 23, 756),
#        datetime.datetime(2020, 12, 27, 8, 34, 11, 756),
#        datetime.datetime(2020, 12, 27, 8, 34, 27, 756),
#        datetime.datetime(2020, 12, 27, 8, 34, 59, 756),
#        datetime.datetime(2020, 12, 27, 8, 36, 35, 756),
#        datetime.datetime(2020, 12, 27, 8, 37, 23, 756),
#        datetime.datetime(2020, 12, 27, 9, 2, 27, 759),
#        datetime.datetime(2020, 12, 27, 9, 2, 43, 759),
#        datetime.datetime(2020, 12, 27, 9, 3, 15, 759),
#        datetime.datetime(2020, 12, 27, 9, 4, 3, 759),
#        datetime.datetime(2020, 12, 27, 9, 4, 19, 759),
#        datetime.datetime(2020, 12, 27, 9, 4, 51, 759),
#        datetime.datetime(2020, 12, 27, 9, 5, 7, 759),
#        datetime.datetime(2020, 12, 27, 9, 5, 23, 759),
#        datetime.datetime(2020, 12, 27, 9, 5, 55, 759),
#        datetime.datetime(2020, 12, 27, 9, 6, 11, 759),
#        datetime.datetime(2020, 12, 27, 9, 6, 43, 759),
#        datetime.datetime(2020, 12, 27, 9, 14, 59, 760),
#        datetime.datetime(2020, 12, 27, 9, 55, 31, 764),
#        datetime.datetime(2020, 12, 27, 9, 59, 15, 764),
#        datetime.datetime(2020, 12, 27, 9, 59, 31, 764),
#        datetime.datetime(2020, 12, 27, 9, 59, 47, 764),
#        datetime.datetime(2020, 12, 27, 10, 0, 19, 764),
#        datetime.datetime(2020, 12, 27, 10, 0, 35, 764),
#        datetime.datetime(2020, 12, 27, 10, 1, 7, 765),
#        datetime.datetime(2020, 12, 27, 10, 1, 55, 765),
#        datetime.datetime(2020, 12, 27, 10, 2, 59, 765),
#        datetime.datetime(2020, 12, 27, 10, 3, 15, 765),
#        datetime.datetime(2020, 12, 27, 10, 4, 19, 765),
#        datetime.datetime(2020, 12, 27, 10, 4, 35, 765),
#        datetime.datetime(2020, 12, 27, 10, 4, 51, 765),
#        datetime.datetime(2020, 12, 27, 10, 5, 39, 765),
#        datetime.datetime(2020, 12, 27, 10, 5, 55, 765),
#        datetime.datetime(2020, 12, 27, 10, 6, 11, 765),
#        datetime.datetime(2020, 12, 27, 10, 6, 27, 765),
#        datetime.datetime(2020, 12, 27, 10, 6, 59, 765),
#        datetime.datetime(2020, 12, 27, 10, 7, 31, 765),
#        datetime.datetime(2020, 12, 27, 10, 7, 47, 765),
#        datetime.datetime(2020, 12, 27, 10, 8, 3, 765),
#        datetime.datetime(2020, 12, 27, 10, 8, 19, 765),
#        datetime.datetime(2020, 12, 27, 10, 8, 35, 765),
#        datetime.datetime(2020, 12, 27, 10, 9, 23, 765),
#        datetime.datetime(2020, 12, 27, 10, 9, 39, 765),
#        datetime.datetime(2020, 12, 27, 10, 9, 55, 765),
#        datetime.datetime(2020, 12, 27, 10, 10, 27, 765),
#        datetime.datetime(2020, 12, 27, 10, 10, 59, 766),
#        datetime.datetime(2020, 12, 27, 10, 11, 15, 766),
#        datetime.datetime(2020, 12, 27, 10, 11, 31, 766),
#        datetime.datetime(2020, 12, 27, 10, 11, 47, 766),
#        datetime.datetime(2020, 12, 27, 10, 12, 3, 766),
#        datetime.datetime(2020, 12, 27, 10, 12, 19, 766),
#        datetime.datetime(2020, 12, 27, 10, 12, 35, 766),
#        datetime.datetime(2020, 12, 27, 10, 12, 51, 766),
#        datetime.datetime(2020, 12, 27, 10, 13, 7, 766),
#        datetime.datetime(2020, 12, 27, 10, 13, 23, 766),
#        datetime.datetime(2020, 12, 27, 10, 13, 39, 766),
#        datetime.datetime(2020, 12, 27, 10, 14, 11, 766),
#        datetime.datetime(2020, 12, 27, 10, 14, 27, 766),
#        datetime.datetime(2020, 12, 27, 10, 14, 43, 766),
#        datetime.datetime(2020, 12, 27, 10, 14, 59, 766),
#        datetime.datetime(2020, 12, 27, 10, 15, 15, 766),
#        datetime.datetime(2020, 12, 27, 10, 15, 31, 766),
#        datetime.datetime(2020, 12, 27, 10, 15, 47, 766),
#        datetime.datetime(2020, 12, 27, 10, 16, 3, 766),
#        datetime.datetime(2020, 12, 27, 10, 17, 39, 766),
#        datetime.datetime(2020, 12, 27, 10, 18, 43, 766),
#        datetime.datetime(2020, 12, 27, 10, 24, 35, 767),
#        datetime.datetime(2020, 12, 27, 10, 24, 51, 767),
#        datetime.datetime(2020, 12, 27, 10, 26, 11, 767),
#        datetime.datetime(2020, 12, 27, 10, 26, 27, 767),
#        datetime.datetime(2020, 12, 27, 10, 26, 43, 767),
#        datetime.datetime(2020, 12, 27, 10, 26, 59, 767),
#        datetime.datetime(2020, 12, 27, 10, 27, 15, 767),
#        datetime.datetime(2020, 12, 27, 10, 27, 47, 767),
#        datetime.datetime(2020, 12, 27, 10, 28, 3, 767),
#        datetime.datetime(2020, 12, 27, 10, 28, 19, 767),
#        datetime.datetime(2020, 12, 27, 10, 28, 35, 767),
#        datetime.datetime(2020, 12, 27, 10, 28, 51, 767),
#        datetime.datetime(2020, 12, 27, 10, 29, 23, 767),
#        datetime.datetime(2020, 12, 27, 10, 29, 39, 767),
#        datetime.datetime(2020, 12, 27, 10, 29, 55, 767),
#        datetime.datetime(2020, 12, 27, 10, 30, 11, 767),
#        datetime.datetime(2020, 12, 27, 10, 30, 43, 767),
#        datetime.datetime(2020, 12, 27, 10, 30, 59, 768),
#        datetime.datetime(2020, 12, 27, 10, 31, 15, 768),
#        datetime.datetime(2020, 12, 27, 10, 31, 47, 768),
#        datetime.datetime(2020, 12, 27, 10, 32, 35, 768),
#        datetime.datetime(2020, 12, 27, 10, 33, 23, 768),
#        datetime.datetime(2021, 5, 9, 16, 20, 49, 132),
#        datetime.datetime(2021, 5, 9, 16, 21, 37, 132),
#        datetime.datetime(2021, 5, 22, 0, 41, 18, 899),
#        datetime.datetime(2021, 5, 22, 7, 31, 58, 940),
#        datetime.datetime(2021, 5, 22, 7, 32, 46, 940),
#        datetime.datetime(2021, 5, 22, 7, 33, 2, 940),
#        datetime.datetime(2021, 5, 22, 7, 33, 18, 940),
#        datetime.datetime(2021, 5, 22, 7, 33, 34, 940),
#        datetime.datetime(2021, 5, 22, 7, 34, 6, 941),
#        datetime.datetime(2021, 5, 22, 7, 34, 22, 941),
#        datetime.datetime(2021, 5, 22, 7, 34, 38, 941),
#        datetime.datetime(2021, 5, 22, 7, 34, 54, 941),
#        datetime.datetime(2021, 5, 22, 7, 35, 42, 941),
#        datetime.datetime(2021, 5, 22, 7, 35, 58, 941),
#        datetime.datetime(2021, 5, 22, 7, 36, 14, 941),
#        datetime.datetime(2021, 5, 22, 7, 37, 2, 941),
#        datetime.datetime(2021, 5, 22, 7, 38, 6, 941),
#        datetime.datetime(2021, 5, 22, 7, 38, 22, 941),
#        datetime.datetime(2021, 5, 22, 7, 38, 38, 941),
#        datetime.datetime(2021, 5, 22, 7, 38, 54, 941),
#        datetime.datetime(2021, 5, 22, 7, 39, 10, 941),
#        datetime.datetime(2021, 5, 22, 7, 39, 58, 941),
#        datetime.datetime(2021, 5, 22, 7, 40, 14, 941),
#        datetime.datetime(2021, 5, 22, 7, 40, 46, 941),
#        datetime.datetime(2021, 5, 22, 7, 41, 2, 941),
#        datetime.datetime(2021, 5, 22, 7, 41, 34, 941),
#        datetime.datetime(2021, 5, 22, 7, 42, 6, 941),
#        datetime.datetime(2021, 5, 22, 7, 42, 54, 941),
#        datetime.datetime(2021, 5, 22, 7, 43, 10, 941),
#        datetime.datetime(2021, 5, 22, 7, 46, 22, 942),
#        datetime.datetime(2021, 5, 22, 7, 46, 38, 942),
#        datetime.datetime(2021, 5, 22, 7, 46, 54, 942),
#        datetime.datetime(2021, 5, 22, 7, 47, 10, 942),
#        datetime.datetime(2021, 5, 22, 7, 47, 26, 942),
#        datetime.datetime(2021, 5, 22, 7, 48, 14, 942),
#        datetime.datetime(2021, 5, 22, 7, 48, 30, 942),
#        datetime.datetime(2021, 5, 22, 7, 48, 46, 942),
#        datetime.datetime(2021, 5, 22, 7, 49, 18, 942),
#        datetime.datetime(2021, 5, 22, 7, 49, 34, 942),
#        datetime.datetime(2021, 5, 22, 7, 49, 50, 942),
#        datetime.datetime(2021, 5, 22, 7, 50, 22, 942),
#        datetime.datetime(2021, 5, 22, 7, 51, 10, 942),
#        datetime.datetime(2021, 5, 23, 8, 56, 35, 92),
#        datetime.datetime(2021, 5, 23, 8, 56, 51, 92),
#        datetime.datetime(2021, 5, 23, 8, 57, 7, 92),
#        datetime.datetime(2021, 5, 23, 8, 57, 23, 92),
#        datetime.datetime(2021, 5, 23, 8, 57, 39, 92),
#        datetime.datetime(2021, 5, 23, 9, 1, 7, 92),
#        datetime.datetime(2021, 5, 23, 9, 1, 23, 92),
#        datetime.datetime(2021, 5, 23, 9, 1, 39, 92),
#        datetime.datetime(2021, 5, 23, 9, 1, 55, 92),
#        datetime.datetime(2021, 5, 23, 9, 2, 11, 92),
#        datetime.datetime(2021, 5, 23, 9, 2, 27, 92),
#        datetime.datetime(2021, 5, 23, 9, 2, 43, 93),
#        datetime.datetime(2021, 5, 23, 9, 2, 59, 93),
#        datetime.datetime(2021, 5, 23, 9, 3, 15, 93),
#        datetime.datetime(2021, 5, 23, 9, 3, 31, 93),
#        datetime.datetime(2021, 5, 23, 10, 15, 15, 100),
#        datetime.datetime(2021, 5, 23, 10, 15, 31, 100),
#        datetime.datetime(2021, 5, 23, 10, 16, 19, 100),
#        datetime.datetime(2021, 5, 23, 10, 17, 7, 100),
#        datetime.datetime(2021, 5, 23, 10, 17, 39, 100),
#        datetime.datetime(2021, 5, 23, 10, 17, 55, 100),
#        datetime.datetime(2021, 5, 23, 10, 20, 3, 100),
#        datetime.datetime(2021, 5, 23, 10, 20, 19, 100),
#        datetime.datetime(2021, 5, 23, 11, 29, 7, 107),
#        datetime.datetime(2021, 5, 23, 11, 29, 23, 107),
#        datetime.datetime(2021, 5, 23, 11, 29, 39, 107),
#        datetime.datetime(2021, 5, 23, 11, 29, 55, 107),
#        datetime.datetime(2021, 5, 23, 11, 30, 11, 107),
#        datetime.datetime(2021, 5, 23, 11, 30, 27, 107),
#        datetime.datetime(2021, 5, 23, 11, 30, 43, 107),
#        datetime.datetime(2021, 5, 23, 11, 30, 59, 107),
#        datetime.datetime(2021, 5, 23, 11, 31, 15, 107),
#        datetime.datetime(2021, 5, 23, 11, 31, 31, 107),
#        datetime.datetime(2021, 5, 23, 11, 31, 47, 107),
#        datetime.datetime(2021, 5, 23, 11, 32, 3, 107),
#        datetime.datetime(2021, 5, 23, 11, 38, 59, 108),
#        datetime.datetime(2021, 5, 23, 11, 39, 15, 108),
#        datetime.datetime(2021, 5, 23, 11, 39, 31, 108),
#        datetime.datetime(2021, 5, 23, 11, 39, 47, 108),
#        datetime.datetime(2021, 5, 23, 11, 40, 19, 108),
#        datetime.datetime(2021, 5, 23, 11, 40, 35, 108),
#        datetime.datetime(2021, 5, 23, 11, 43, 15, 108),
#        datetime.datetime(2021, 5, 25, 7, 49, 35, 372),
#        datetime.datetime(2021, 5, 31, 19, 38, 24, 301),
#        datetime.datetime(2021, 5, 31, 19, 38, 40, 301),
#        datetime.datetime(2021, 5, 31, 19, 38, 56, 301),
#        datetime.datetime(2021, 5, 31, 19, 39, 28, 301),
#        datetime.datetime(2021, 5, 31, 19, 39, 44, 301),
#        datetime.datetime(2021, 5, 31, 19, 40, 0, 301),
#        datetime.datetime(2021, 5, 31, 19, 40, 16, 301),
#        datetime.datetime(2021, 5, 31, 19, 40, 32, 301),
#        datetime.datetime(2021, 5, 31, 19, 41, 4, 301),
#        datetime.datetime(2021, 5, 31, 19, 41, 36, 301),
#        datetime.datetime(2021, 5, 31, 19, 41, 52, 301),
#        datetime.datetime(2021, 5, 31, 19, 59, 12, 303),
#        datetime.datetime(2021, 5, 31, 20, 1, 4, 303),
#        datetime.datetime(2021, 6, 1, 2, 24, 32, 342),
#        datetime.datetime(2021, 6, 1, 2, 24, 48, 342),
#        datetime.datetime(2021, 6, 1, 2, 25, 4, 342),
#        datetime.datetime(2021, 6, 4, 11, 5, 56, 823),
#        datetime.datetime(2021, 6, 4, 11, 6, 28, 823),
#        datetime.datetime(2021, 6, 4, 20, 39, 32, 880),
#        datetime.datetime(2021, 6, 7, 20, 2, 45, 306),
#        datetime.datetime(2021, 6, 7, 20, 3, 1, 306),
#        datetime.datetime(2021, 6, 7, 20, 3, 17, 306),
#        datetime.datetime(2021, 6, 7, 20, 3, 49, 306)], dtype=object)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md
plt.plot(rua)

# %%
ax = plt.gca()
xfmt = md.DateFormatter('%y-%m')
ax.xaxis.set_major_formatter(xfmt)
plt.plot(time, rua)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
with open('SBM2_timepos_data_V6.pickle', 'rb') as f:
        time, rua, Epoch, et = pickle.load(f)
ax = plt.gca()
xfmt = md.DateFormatter('%y-%m')
ax.xaxis.set_major_formatter(xfmt)
plt.plot(time, EV)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# CONFIGURATION CELL #
# Confirmation default 
condef = {'EPEAK_THRES': 200, 'FP_MIN': 5000, 'FP_MAX': 50000, 'NW_THRES': 2, 'DT_LW': 304,  'N_LW_THRES': 5 , 'title': '_confirmation', 'type': 'default'}

# Degraded default ('_F' is removed for convenience)
degdef = {'EPEAK_THRES': 728, 'FP_MIN': 5000, 'FP_MAX': 50000, 'NW_THRES': 3, 'DT_LW': 1200, 'N_LW_THRES': 20, 'title': '_degraded', 'type': 'default'}

# Outdated confirmation default 
ocondef = {'EPEAK_THRES': 728, 'FP_MIN': 5000, 'FP_MAX': 60000, 'NW_THRES': 3, 'DT_LW': 2400, 'N_LW_THRES': 20, 'title': 'confirmation', 'type': 'outdated-default'}

# Outdated degraded default ('_F' is removed for convenience)
odegdef = {'EPEAK_THRES': 728, 'FP_MIN': 5000, 'FP_MAX': 60000, 'NW_THRES': 3, 'DT_LW': 1200, 'N_LW_THRES': 20, 'title': 'degraded', 'type': 'outdated-default'}

# Custom config 1
custom1 = {'EPEAK_THRES': 200, 'FP_MIN': 5000, 'FP_MAX': 50000, 'NW_THRES': 1, 'DT_LW': 1200,  'N_LW_THRES': 5 , 'title': 'custom1', 'type': 'dev'}

# Custom config 2
custom2 = {'EPEAK_THRES': 150, 'FP_MIN': 5000, 'FP_MAX': 50000, 'NW_THRES': 1, 'DT_LW': 1200,  'N_LW_THRES': 5 , 'title': 'custom2', 'type': 'dev'}
