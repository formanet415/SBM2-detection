# %%
import load_cdf as cdf
import numpy as np
import math
from calendar import monthrange
from collections import namedtuple
import pickle
import scipy.io 
import scipy.signal

import cdflib 
import matplotlib.dates as md
import matplotlib
from matplotlib import pyplot as plt
import datetime as dt
matplotlib.rcParams['figure.figsize'] = [12, 8]

# %%
Date = namedtuple("Date", ["year", "month", "day"])
def all_dates_in_year(year):
    Fp = np.array([])
    WA_AMP_MED = np.array([])
    WA_NR_EVENTS = np.array([])
    time = np.array([])
    Epoch = np.array([])
    for month in range(1, 13): # Month is always 1..12
        for day in range(1, monthrange(year, month)[1] + 1):
            Fp1, WA_AMP_MED1, WA_NR_EVENTS1, time1, Epoch1 = check_date(year, month, day)
            if not isinstance(Fp1, int):
                Fp = np.append(Fp, Fp1)
                WA_AMP_MED = np.append(WA_AMP_MED, WA_AMP_MED1)
                WA_NR_EVENTS = np.append(WA_NR_EVENTS, WA_NR_EVENTS1)
                time = np.append(time, time1)
                Epoch = np.append(Epoch, Epoch1)
    return [Fp, WA_AMP_MED, WA_NR_EVENTS, time, Epoch]

# %%
def check_date(year, month, day):
    data = cdf.load_rpw('stat', year, month, day, 'L1')
    if data != -1:
        print('Checking %04d%02d%02d_V' % (year, month, day))
        return SBM_degraded(data)
    else:
        return [-1,-1,-1,-1,-1]

# %%
def SBM_degraded(data):
    time = cdflib.cdfepoch.to_datetime(data['Epoch'])
    Epoch = data['Epoch']
    #time =[dt.datetime.fromtimestamp(ts) for ts in time]
    Fp = 1024 * 2 ** (data['WA_MED_FREQ'] / 32)
    WA_AMP_MED = data['WA_AMP_MED']
    WA_NR_EVENTS = data['WA_NR_EVENTS']
    
    # CONSTANTS 
    #EPEAK_THRES_F = 750
    #FP_MIN = 5000   #Hz
    #FP_MAX = 60000  #Hz
    #RUA = 0.5       #AU  ??
    #NW_THRES_F = 3
    
    return [Fp, WA_AMP_MED, WA_NR_EVENTS, time, Epoch]

# %%
Fp = []
WA_AMP_MED = []
WA_NR_EVENTS = []
time = []
Epoch = []
for i in [2020,2021]:
    [Fp21, WA_AMP_MED21, WA_NR_EVENTS21, time21, Epoch21] = all_dates_in_year(i)
    Fp = np.append(Fp, Fp21)
    WA_AMP_MED = np.append(WA_AMP_MED, WA_AMP_MED21)
    WA_NR_EVENTS = np.append(WA_NR_EVENTS, WA_NR_EVENTS21)
    time = np.append(time, time21)
    Epoch = np.append(Epoch, Epoch21)
# Out:
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Checking 20200225_V
# Checking 20200226_V
# Checking 20200227_V
# Checking 20200228_V
# Checking 20200229_V
# Checking 20200301_V
# Checking 20200302_V
# Checking 20200303_V
# Checking 20200304_V
# Checking 20200305_V
# Checking 20200306_V
# Checking 20200307_V
# Checking 20200308_V
# Checking 20200309_V
# Checking 20200310_V
# Checking 20200311_V
# Checking 20200312_V
# Checking 20200313_V
# Checking 20200314_V
# Checking 20200315_V
# Checking 20200316_V
# Checking 20200317_V
# Checking 20200318_V
# Checking 20200319_V
# Checking 20200320_V
# Checking 20200321_V
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Checking 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8cf7a629769e> in <module>
#       5 Epoch = []
#       6 for i in [2020,2021]:
# ----> 7     [Fp21, WA_AMP_MED21, WA_NR_EVENTS21, time21, Epoch21] = all_dates_in_year(i)
#       8     Fp = np.append(Fp, Fp21)
#       9     WA_AMP_MED = np.append(WA_AMP_MED, WA_AMP_MED21)
#
# <ipython-input-2-8313c8fb3905> in all_dates_in_year(year)
#       8     for month in range(1, 13): # Month is always 1..12
#       9         for day in range(1, monthrange(year, month)[1] + 1):
# ---> 10             Fp1, WA_AMP_MED1, WA_NR_EVENTS1, time1, Epoch1 = check_date(year, month, day)
#      11             if not isinstance(Fp1, int):
#      12                 Fp = np.append(Fp, Fp1)
#
# <ipython-input-3-99c219bb437d> in check_date(year, month, day)
#       1 def check_date(year, month, day):
# ----> 2     data = cdf.load_rpw('stat', year, month, day, 'L1')
#       3     if data != -1:
#       4         print('Checking %04d%02d%02d_V' % (year, month, day))
#       5         return SBM_degraded(data)
#
# ~\Documents\GitHub\SBM2-detection\load_cdf.py in load_rpw(filetype, year, month, day, opt)
#      39         data = {}
#      40
# ---> 41         (why, varnames) = cdf._get_varnames()
#      42         for varname in varnames:
#      43             data[varname] = cdf.varget(varname)
#
# ~\miniconda3\envs\legitconda\lib\site-packages\cdflib\cdfread.py in _get_varnames(self)
#     872             num_variable = self._num_zvariable
#     873             for _ in range(0, num_variable):
# --> 874                 name, next_vdr = self._read_vdr_fast(position)
#     875                 zvars.append(name)
#     876                 position = next_vdr
#
# ~\miniconda3\envs\legitconda\lib\site-packages\cdflib\cdfread.py in _read_vdr_fast(self, byte_loc)
#    1560     def _read_vdr_fast(self, byte_loc):
#    1561         if self.cdfversion == 3:
# -> 1562             return self._read_vdr_fast3(byte_loc)
#    1563         else:
#    1564             return self._read_vdr_fast2(byte_loc)
#
# ~\miniconda3\envs\legitconda\lib\site-packages\cdflib\cdfread.py in _read_vdr_fast3(self, byte_loc)
#    1567         with self.file.open('rb') as f:
#    1568             f.seek(byte_loc+12, 0)
# -> 1569             next_vdr = int.from_bytes(f.read(8), 'big', signed=True)
#    1570             f.seek(byte_loc+84, 0)
#    1571             name = str(f.read(256).decode(self.string_encoding))
#
# KeyboardInterrupt:

# %%
Fp = []
WA_AMP_MED = []
WA_NR_EVENTS = []
time = []
Epoch = []
for i in [2021]:
    [Fp21, WA_AMP_MED21, WA_NR_EVENTS21, time21, Epoch21] = all_dates_in_year(i)
    Fp = np.append(Fp, Fp21)
    WA_AMP_MED = np.append(WA_AMP_MED, WA_AMP_MED21)
    WA_NR_EVENTS = np.append(WA_NR_EVENTS, WA_NR_EVENTS21)
    time = np.append(time, time21)
    Epoch = np.append(Epoch, Epoch21)
# Out:
# Checking 20210101_V
# Checking 20210102_V
# Checking 20210103_V
# Checking 20210104_V
# Checking 20210105_V
# Checking 20210106_V
# Checking 20210107_V
# Checking 20210108_V
# Checking 20210109_V
# Checking 20210110_V
# Checking 20210111_V
# Checking 20210112_V
# Checking 20210113_V
# Checking 20210114_V
# Checking 20210115_V
# Checking 20210116_V
# Checking 20210117_V
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Checking 
# Checking 20210630_V
# Checking 20210701_V
# Checking 20210702_V
# Checking 20210703_V
# Checking 20210704_V
# Checking 20210705_V
# Checking 20210706_V
# Checking 20210707_V
# Checking 20210708_V
# Checking 20210709_V
# Checking 20210710_V
# Checking 20210711_V
# Checking 20210712_V
# Checking 20210713_V
# Checking 20210714_V
# Checking 20210715_V
# Checking 20210716_V
# Checking 20210717_V
# Checking 20210718_V
# Checking 20210719_V
# Checking 20210720_V
# Checking 20210721_V
# Checking 20210722_V
# Checking 20210723_V
# Checking 20210724_V
# Checking 20210725_V
# Checking 20210726_V
# Checking 20210727_V
# Checking 20210728_V
# Checking 20210729_V
# Checking 20210730_V
# Checking 20210731_V
# Checking 20210801_V
# Checking 20210802_V
# Checking 20210803_V
# Checking 20210804_V
# Checking 20210805_V
# Checking 20210806_V
# Checking 20210807_V
# Checking 20210808_V
# Checking 20210809_V
# Checking 20210810_V
# Checking 20210811_V
# Checking 20210812_V
# Checking 20210813_V
# Checking 20210814_V
# Checking 20210815_V
# Checking 20210816_V
# Checking 20210817_V
# Checking 20210818_V
# Checking 20210819_V
# Checking 20210820_V
# Checking 20210821_V
# Checking 20210822_V
# Checking 20210823_V
# Checking 20210824_V
# Checking 20210825_V
# Checking 20210826_V
# Checking 20210827_V
# Checking 20210828_V
# Checking 20210829_V
# Checking 20210830_V
# Checking 20210831_V
# Checking 20210901_V
# Checking 20210902_V
# Checking 20210903_V
# Checking 20210904_V
# Checking 20210905_V
# Checking 20210906_V
# Checking 20210907_V
# Checking 20210908_V
# Checking 20210909_V
# Checking 20210910_V
# Checking 20210911_V
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Checking 20210920_V
# Checking 20210921_V
# Checking 20210922_V
# Checking 20210923_V
# Checking 20210924_V
# Checking 20210925_V
# Checking 20210926_V
# Checking 20210927_V
# Checking 20210928_V
# Checking 20210929_V
# Checking 20210930_V
# Checking 20211001_V
# Checking 20211002_V
# Checking 20211003_V
# Checking 20211004_V
# Checking 20211005_V
# Checking 20211006_V
# Checking 20211007_V
# Checking 20211008_V
# Checking 20211009_V
# Checking 20211010_V
# Checking 20211011_V
# Checking 20211012_V
# Checking 20211013_V
# Checking 20211014_V
# Checking 20211015_V
# Checking 20211016_V
# Checking 20211017_V
# Checking 20211018_V
# Checking 20211019_V
# Checking 20211020_V
# Checking 20211021_V
# Checking 20211022_V
# Checking 20211023_V
# Checking 20211024_V
# Checking 20211025_V
# Checking 20211026_V
# Checking 20211027_V
# Checking 20211028_V
# Checking 20211029_V
# Checking 20211030_V
# Checking 20211031_V
# Checking 20211101_V
# Checking 20211102_V
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found

# %%
Fp = []
WA_AMP_MED = []
WA_NR_EVENTS = []
time = []
Epoch = []
for i in [2020]:
    [Fp21, WA_AMP_MED21, WA_NR_EVENTS21, time21, Epoch21] = all_dates_in_year(i)
    Fp = np.append(Fp, Fp21)
    WA_AMP_MED = np.append(WA_AMP_MED, WA_AMP_MED21)
    WA_NR_EVENTS = np.append(WA_NR_EVENTS, WA_NR_EVENTS21)
    time = np.append(time, time21)
    Epoch = np.append(Epoch, Epoch21)
# Out:
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Checking 20
V
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Checking 20200819_V
# Checking 20200820_V
# Checking 20200821_V
# Checking 20200822_V
# Checking 20200823_V
# Checking 20200824_V
# Checking 20200825_V
# Checking 20200826_V
# Checking 20200827_V
# Checking 20200828_V
# Checking 20200829_V
# Checking 20200830_V
# Checking 20200831_V
# Checking 20200901_V
# Checking 20200902_V
# Checking 20200903_V
# Checking 20200904_V
# Checking 20200905_V
# Checking 20200906_V
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Dir not found
# Checking 20200914_V
# Checking 20200915_V
# Checking 20200916_V
# Checking 20200917_V
# Checking 20200918_V
# Checking 20200919_V
# Checking 20200920_V
# Checking 20200921_V
# Checking 20200922_V
# Checking 20200923_V
# Checking 20200924_V
# Checking 20200925_V
# Checking 20200926_V
# Checking 20200927_V
# Checking 20200928_V
# Checking 20200929_V
# Checking 20200930_V
# Checking 20201001_V
# Checking 20201002_V
# Checking 20201003_V
# Checking 20201004_V
# Checking 20201005_V
# Checking 20201006_V
# Checking 20201007_V
# Checking 20201008_V
# Checking 20201009_V
# Checking 20201010_V
# Checking 20201011_V
# Checking 20201012_V
# Checking 20201013_V
# Checking 20201014_V
# Checking 20201015_V
# Checking 20201016_V
# Checking 20201017_V
# Checking 20201018_V
# Checking 20201019_V
# Checking 20201020_V
# Checking 20201021_V
# Checking 20201022_V
# Checking 20201023_V
# Checking 20201024_V
# Checking 20201025_V
# Checking 20201026_V
# Checking 20201027_V
# Checking 20201028_V
# Checking 20201029_V
# Checking 20201030_V
# Checking 20201031_V
# Checking 20201101_V
# Checking 20201102_V
# Checking 20201103_V
# Checking 20201104_V
# Checking 20201105_V
# Checking 20201106_V
# Checking 20201107_V
# Checking 20201108_V
# Checking 20201109_V
# Checking 20201110_V
# Checking 20201111_V
# Checking 20201112_V
# Checking 20201113_V
# Checking 20201114_V
# Checking 20201115_V
# Checking 20201116_V
# Checking 20201117_V
# Checking 20201118_V
# Checking 20201119_V
# Checking 20201120_V
# Checking 20201121_V
# Checking 20201122_V
# Checking 20201123_V
# Checking 20201124_V
# Checking 20201125_V
# Checking 20201126_V
# Checking 20201127_V
# Checking 20201128_V
# Checking 20201129_V
# Checking 20201130_V
# Checking 20201201_V
# Checking 20201202_V
# Checking 20201203_V
# Checking 20201204_V
# Checking 20201205_V
# Checking 20201206_V
# Checking 20201207_V
# Checking 20201208_V
# Checking 20201209_V
# Checking 20201210_V
# Checking 20201211_V
# Checking 20201212_V
# Checking 20201213_V
# Checking 20201214_V
# Checking 20201215_V
# Checking 20201216_V
# Checking 20201217_V
# Checking 20201218_V
# Checking 20201219_V
# Checking 20201220_V
# Checking 20201221_V
# Checking 20201222_V
# Checking 20201223_V
# Checking 20201224_V
# Checking 20201225_V
# Checking 20201226_V
# Checking 20201227_V
# Checking 20201228_V
# Checking 20201229_V
# Checking 20201230_V
# Checking 20201231_V

# %%
Epoch.shape
# Out:
# (2825482,)

# %%
time.shape
# Out:
# (2825482,)

# %%
Fp.shape
# Out:
# (2825482,)

# %%
# Save data
with open('SBM2_data_2020_V7.3_final.pickle', 'wb') as f:
    pickle.dump([Fp, WA_AMP_MED, WA_NR_EVENTS, time, Epoch], f)

# %%
with open('SBM2_data_V7.2.pickle', 'rb') as f:
    Fp, WA_AMP_MED, WA_NR_EVENTS, time, Epoch = pickle.load(f)
